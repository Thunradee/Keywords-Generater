# %% [markdown]
# # Keywords Generation From PDF File
#
# ## Introduction
# This notebook aims to generate keywords for scientific papers that posted online as PDF files. We do this by
#
# 1. <b>Getting Data</b> - we collect a url of papers from our database.
# 2. <b>Keywords Generation</b>
#     We try generating keywords by using data engineering and machine learning libraries.
#   - Keywords matching - We read in content of online pdf file, then count occurrence of each word in our pre-listed keywords list and select 5 highest words.
#   - SpaCy
#   - YAKE
#   - Rake-Nltk
#   - Gensim

# %% [markdown]
# ## 1. Getting Data

# %%
# Connect with database
from pymongo import MongoClient

DB_NAME = 'TechVault'
COLLECTION_NAME = 'blogs'

mongo_uri = "mongodb+srv://gift:t@cluster0.kf3n4.mongodb.net/{}?authSource=admin&ssl=true".format(DB_NAME)
client = MongoClient(mongo_uri)

# Database: TechVault
db = client[DB_NAME]

# Collection: blogs
collection = db[COLLECTION_NAME]

# %%
# Read all papers

papers = []

for doc in collection.find():
    if doc['type'] == 'paper':
        # collect only title and abstract
        paper = {'url': doc['link']}
        papers.append(paper)

papers[0]
# Out:
# {'url': 'https://arxiv.org/pdf/0704.0062'}

# %% [markdown]
# ## 2. Keywords Generation
# ### 2.1 Keywords Matching

# %%
# Dictionary of keywords
# Key: Searching words
# Value: Displayed words

keywords = {"Machine Learning": "Machine Learning",
            "Supervised Learning": "Supervised Learning",
            "Unsupervised Learning": "Unsupervised Learning",
            "Multilabel Classification": "Multilabel Classification",
            "Clustering": "Clustering",
            "K-Means": "K-Means",
            "DBSCAN": "DBSCAN",
            "Hierarchical Clustering": "Hierarchical Clustering",
            "Deep Learning": "Deep Learning",
            "Data Mining": "Data Mining",
            "Linear regression": "Linear regression",
            "Logistic regression": "Logistic regression",
            "SVM": "SVM",
            "Natural Language Processing": "Natural Language Processing",
            "Computer Vision": "Computer Vision",
            "KNN": "KNN",
            "Random forest": "Random forest",
            "Decision Tree": "Decision Tree",
            "Regularization": "Regularization",
            "Ensemble Learning": "Ensemble Learning",
            "Gradient Boosting": "Gradient Boosting",
            "Feature Selection": "Feature Selection",
            "Reinforcement Learning": "Reinforcement Learning",
            "Virtual Reality": "Virtual Reality",
            "Augmented reality": "Augmented reality",
            "Autonomous driving": "Autonomous driving",
            "Optics": "Optics",
            "Biology": "Biology",
            "C++": "C++",
            "Java": "Java",
            "Python": "Python",
            "React JS": "React JS",
            "Computer Network": "Computer Networks",  # remove s
            "Frontend": "Frontend",
            "Backend": "Backend",
            "High Scalability": "High Scalability",
            "Cloud computing": "Cloud computing",
            "Parallel Computing": "Parallel Computing",
            "CUDA": "CUDA",
            "Distributed System": "Distributed Systems",  # remove s
            "Apache ZooKeeper": "Apache ZooKeeper",
            "Streaming analytic": "Streaming analytics",
            "Model Selection": "Model Selection",
            "Model Evaluation": "Model Evaluation",
            "Apache Kafka": "Apache Kafka",
            "HDFS": "HDFS",
            "Amazon S3": "Amazon S3",
            "Pub-Sub": "Pub-Sub",
            "Leader Election": "Leader Election",
            "Clock Synchronization": "Clock Synchronization",
            "Graph": "Graphs",  # remove s
            "Information Retrieval": "Information Retrieval",
            "SQL": "SQL",
            "Graph Database": "Graph Database",
            "Database Management": "Database Management",
            "Storage": "Storage",
            "Memor": "Memory",
            "Garbage Collection": "Garbage Collection",
            "Map-Reduce": "Map-Reduce",
            "Network Protocol": "Network Protocols",  # remove s
            "Cyber Security": "Cyber Security",
            "Assembly Language": "Assembly Language",
            "Computational Complexity Theor": "Computational Complexity Theory",
            "Computer Architecture": "Computer Architecture",
            "Human-Computer Interface": "Human-Computer Interface",
            "Data Structure": "Data Structures",  # remove s
            "Discrete Mathematic": "Discrete Mathematics",
            "Hacking": "Hacking",
            "Quantum Computing": "Quantum Computing",
            "Robotic": "Robotics",  # remove s
            "Engineering Practice": "Engineering Practices",  # remove s
            "Software Tool": "Software Tools",  # remove s
            "Mathematical Logic": "Mathematical Logic",
            "Graph Theor": "Graph Theory",
            "Computational Geometr": "Computational Geometry",
            "Compiler": "Compilers",  # remove s
            "Distributed Computing": "Distributed Computing",
            "Software Engineering": "Software Engineering",
            "Bioinformatic": "Bioinformatics",  # remove s
            "Computational Chemistry": "Computational Chemistry",
            "Computational Neuroscience": "Computational Neuroscience",
            "Computational physics": "Computational physics",
            "Numerical algorithm": "Numerical algorithms",  # remove s
            "JavaScript": "JavaScript",
            "HTML": "HTML",
            "Web Development": "Web Development",
            "App Development": "App Development",
            "CSS": "CSS",
            "PHP": "PHP",
            "BlockChain": "BlockChain",
            "Hardware": "Hardware",
            "VLSI": "VLSI",
            "Cluster Computing": "Cluster Computing",
            "Kubernetes": "Kubernetes",
            "Go": "Go-Lang",
            "File System": "File Systems",  # remove s
            "Statistic": "Statistics",  # remove s
            "Optimization": "Optimization",
            "Knowledge Graph": "Knowledge Graph",
            "RNN": "RNN",
            "CNN": "CNN",
            "Physical Design": "Physical Design",
            "Memory management": "Memory management",
            "PCA": "PCA",
            "LDA": "LDA",
            "Feature Engineering": "Feature Engineering",
            "Data manipulation": "Data manipulation",
            "ACID": "ACID",
            "BASE": "BASE",
            "Consistency": "Consistency",
            "Disaster recovery": "Disaster recovery",
            "Replication": "Replication",
            "Fault tolerance": "Fault tolerance",
            "Deployment": "Deployment",
            "Processor": "Processors",  # remove s
            "Multi-Threading": "Multi-Threading",
            "Queue": "Queue",
            "Stack": "Stack",
            "Dynamic Programming": "Dynamic Programming",
            "Graph Traversal": "Graph Traversal",
            "Device": "Devices",  # remove s
            "Data analysis": "Data analysis",
            "Probability": "Probability",
            "Mathematic": "Mathematics",  # remove s
            "Genomic": "Genomics",  # remove s
            "Data Infrastructure": "Data Infrastructure",
            "Software Principles and Practices": "Software Principles and Practices",
            "Image Processing": "Image Processing",
            "Audio Processing": "Audio Processing",
            "Signal Processing": "Signal Processing",
            "Pattern Recognition": "Pattern Recognition",
            "Computation and Language": "Computation and Language",
            "Artificial Intelligence": "Artificial Intelligence",
            "Computation and Language": "Computation and Language",
            "Computational Complexit": "Computational Complexity",
            "Computational Engineering": "Computational Engineering",
            "Finance": "Finance",  # remove "and Science" from "Finance, and Science"
            "Computational Geometry": "Computational Geometry",
            "Game Theory": "Game Theory",  # remove "Computer Science" from "Computer Science and Game Theory"
            "Computer Vision": "Computer Vision",  # break down from "Computer Vision and Pattern Recognition"
            "Pattern Recognition": "Pattern Recognition",  # break down from "Computer Vision and Pattern Recognition"
            "Computers and Society": "Computers and Society",
            "Cryptography and Security": "Cryptography and Security",
            "Data Structure": "Data Structures",  # break down from "Data Structures and Algorithms"
            "Algorithm": "Algorithms",  # break down from "Data Structures and Algorithms"
            "Database": "Databases",  # break down from "Databases; Digital Libraries"
            "Digital Librar": "Digital Libraries",  # break down from "Databases; Digital Libraries"
            "Distributed Computing": "Distributed Computing",  # break down from "Distributed, Parallel, and Cluster Computing"
            "Parallel Computing": "Parallel Computing",  # break down from "Distributed, Parallel, and Cluster Computing"
            "Cluster Computing": "Cluster Computing",  # break down from "Distributed, Parallel, and Cluster Computing"
            "Emerging Technolog": "Emerging Technologies",
            "Formal Language": "Formal Languages",  # break down from "Formal Languages and Automata Theory"
            "Automata Theory": "Automata Theory",  # break down from "Formal Languages and Automata Theory"
            "General Literature": "General Literature",
            "Graphic": "Graphics",  # remove s
            "Human-Computer Interaction": "Human-Computer Interaction",
            "Information Theory": "Information Theory",
            "Logic in Computer Science": "Logic in Computer Science",
            "Mathematical Software": "Mathematical Software",
            "Multiagent System": "Multi-agent Systems",  # remove s from "Systems"
            "Multi-agent System": "Multi-agent Systems",  # remove s from "Systems" and add -
            "Multimedia": "Multimedia",
            "Networking and Internet Architecture": "Networking and Internet Architecture",
            "Neural and Evolutionary Computing": "Neural and Evolutionary Computing",
            "Numerical Analysis": "Numerical Analysis",
            "Operating System": "Operating Systems",  # remove s from "Systems"
            "Performance": "Performance",
            "Programming Language": "Programming Languages",  # remove s 
            "Social and Information Networks": "Social and Information Networks",
            "Software Engineering": "Software Engineering",
            "Sound": "Sound",
            "Symbolic Computation": "Symbolic Computation",
            "Systems and Control": "Systems and Control"
           }

# %%
def countKeywords(text, keywords):
    ''' Count occurence of keywords in the text, return a dict of words and its occurence'''
    d = {}
    text = ' ' + text + ' '
    # Abbreviations list
    abbreviations = ["SVM", "KNN", "CUDA", "HDFS", "SQL", "HTML", "CSS", "PHP",
                    "VLSI", "RNN", "CNN", "PCA", "LDA", "ACID", "BASE"]
    
    for search_word, display_word in keywords.items():
        # 'Go' can be a sub-string of many words, to be precise, we'll search for the word " Go "
        if search_word == "Go":
            search_word = ' ' + search_word + ' '
        
        # Lower the word if it's not an abbreviation
        elif search_word not in abbreviations:
            search_word = search_word.lower()
        
        # Count occurence of searching word (case sensitive)
        oc = text.count(search_word)
        
        # Append to the dictionary if the word occurs 1 or more time
        if oc > 0:
            d[display_word] = oc

    return d

# %%
# Install pdfPlumber package
# pip install pdfplumber

# %%
import pdfplumber
import io
import requests

def readPDF(url):
    ''' 
    Read PDF file from a URL
    Return a text string
    '''
    r = requests.get(url)
    f = io.BytesIO(r.content)
    text = "" # returned text
    try:
        # Open pdf file
        with pdfplumber.open(f) as pdf:
            pages = pdf.pages
            # Iterate through pdf document pages
            for page in pages:
                # Concat page content to text if there are any
                if page.extract_text():
                    text += '\n' + page.extract_text()

        return text
    except:
        print("PDF file is not found!")
        return ""
    

def keywordsFromPaper(url, keywords):
    '''
    Extracts keywords from a pdf document
      String url: a url of a pdf file
      Dict keywords: a dictionary of searched word and displayed word
    Return
      A list of five words that have highest occurences 
    '''
    text = readPDF(url)
    occ = countKeywords(text, keywords)

    # get a list of top 5 words
    result = list(dict(sorted(occ.items(), key=lambda x: x[1], reverse=True)).keys())[:5]
    return result

# %%
for paper in papers:
    print(paper['url'])
    paper['keywords'] = keywordsFromPaper(paper['url'], keywords)
    print(paper['keywords'])
    print()
# Out:
# https://arxiv.org/pdf/0704.0062
# ['Algorithms', 'Memory', 'Probability', 'Genomics', 'Data Structures']
#
# https://arxiv.org/pdf/0704.0098
# ['Statistics', 'Performance', 'Probability', 'Graphs', 'Algorithms']
#
# https://arxiv.org/pdf/0704.0304
# ['Biology', 'Probability', 'Memory', 'Graphs', 'Robotics']
#
# https://arxiv.org/pdf/0704.0050
# ['Algorithms', 'Statistics', 'Memory', 'Mathematics', 'Image Processing']
#
# https://arxiv.org/pdf/0704.0309
# ['Graphs', 'Algorithms']
#
# https://arxiv.org/pdf/0704.0492
# ['Algorithms', 'Probability', 'Optimization', 'Graphs']
#
# https://arxiv.org/pdf/0704.0831
# ['Probability', 'Performance', 'Memory', 'Stack']
#
# https://arxiv.org/pdf/0704.0834
# ['Algorithms', 'Probability', 'Mathematics', 'Graphs', 'Data Structures']
#
# https://arxiv.org/pdf/0704.1068
# ['Algorithms', 'Graphs', 'Databases', 'Queue', 'Graphics']
#
# https://arxiv.org/pdf/0704.2452
# ['Performance', 'Optimization', 'Algorithms', 'Graphs', 'Memory']
#
# https://arxiv.org/pdf/0704.2644
# ['Memory', 'Performance', 'Probability', 'Databases']
#
# https://arxiv.org/pdf/0704.2779
# ['Algorithms', 'Probability', 'Graphs', 'Optimization', 'Memory']
#
# https://arxiv.org/pdf/0704.3402
# ['Probability', 'Performance', 'Stack', 'Algorithms']
#
# https://arxiv.org/pdf/0704.3643
# ['Devices', 'Graphs', 'Clustering', 'CNN', 'Graphics']
#
# https://arxiv.org/pdf/0704.3878
# ['Probability', 'Optimization', 'Queue', 'Performance']
#
# https://arxiv.org/pdf/0704.3904
# ['Graphs', 'Storage', 'Graph Theory', 'Probability', 'Algorithms']
#
# https://arxiv.org/pdf/0704.1358
# ['Graphs', 'Algorithms']
#
# https://arxiv.org/pdf/0704.1411
# ['Performance', 'Memory', 'Optimization', 'Algorithms', 'Computational Complexity']
#
# https://arxiv.org/pdf/0704.2344
# ['Processors', 'Memory', 'Performance', 'Storage', 'Algorithms']
#
# https://arxiv.org/pdf/0704.2808
# ['Algorithms', 'Optimization', 'Graphs', 'Memory', 'Storage']
#
# https://arxiv.org/pdf/0704.3094
# ['Statistics', 'Probability', 'Optimization', 'Mathematics', 'Algorithms']
#
# https://arxiv.org/pdf/0704.3408
# ['Probability', 'Performance', 'Statistics', 'Algorithms', 'Optimization']
#
# https://arxiv.org/pdf/0704.3500
# ['Performance', 'Algorithms', 'Graphs', 'Clustering', 'Databases']
#
# https://arxiv.org/pdf/0704.3890
# ['Algorithms', 'Hardware', 'Clock Synchronization', 'Graphs']
#
# https://arxiv.org/pdf/0704.3905
# ['Algorithms', 'Optimization', 'Memory', 'Performance', 'Feature Selection']
#
# https://arxiv.org/pdf/0705.0010
# ['Graphs', 'Probability', 'Statistics', 'Algorithms', 'Clustering']
#
# https://arxiv.org/pdf/0705.0085
# ['Graphs', 'Algorithms', 'Memory', 'Computational Complexity']
#
# https://arxiv.org/pdf/0704.0213
# PDF file is not found!
# []
#
# https://arxiv.org/pdf/0704.0805
# ['Performance', 'Probability', 'Optimization', 'Algorithms', 'Memory']
#
# https://arxiv.org/pdf/0704.0879
# ['Memory', 'Storage', 'Probability', 'Performance', 'Algorithms']
#
# https://arxiv.org/pdf/0704.3780
# ['Algorithms', 'Optimization', 'Probability', 'Memory', 'Graphs']
#
# https://arxiv.org/pdf/0704.0229
# ['Algorithms', 'Graphs', 'Processors', 'Mathematics', 'Optimization']
#
# https://arxiv.org/pdf/0704.0730
# ['Statistics', 'Memory', 'Probability', 'Performance', 'Algorithms']
#
# https://arxiv.org/pdf/0704.0861
# ['Graphs', 'Statistics', 'Probability', 'Graphics', 'Clustering']
#
# https://arxiv.org/pdf/0704.1028
# ['Machine Learning', 'SVM', 'Performance', 'Probability', 'Algorithms']
#
# https://arxiv.org/pdf/0704.1873
# ['Probability', 'Memory', 'Statistics']
#
# https://arxiv.org/pdf/0704.2014
# ['Probability', 'Consistency', 'Graphs', 'Multi-agent Systems', 'Game Theory']
#
# https://arxiv.org/pdf/0704.2448
# ['Graphs', 'Stack', 'Sound', 'Algorithms', 'Garbage Collection']
#
# https://arxiv.org/pdf/0704.2475
# ['Performance', 'Graphs', 'Probability', 'Optimization', 'Consistency']
#
# https://arxiv.org/pdf/0704.2778
# ['Queue', 'Probability', 'Optimization', 'Algorithms', 'Performance']
#
# https://arxiv.org/pdf/0704.3396
# ['Algorithms', 'Performance', 'Optimization', 'Probability', 'Graphs']
#
# https://arxiv.org/pdf/0704.3588
# ['Algorithms', 'Optimization', 'Performance', 'Stack', 'Deployment']
#
# https://arxiv.org/pdf/0704.3647
# ['Storage', 'Replication', 'Hacking', 'Databases', 'Multimedia']
#
# https://arxiv.org/pdf/0704.1070
# ['Probability', 'Performance', 'Statistics']
#
# https://arxiv.org/pdf/0704.2259
# ['Probability', 'Memory', 'Performance', 'Graphs', 'Algorithms']
#
# https://arxiv.org/pdf/0704.2507
# ['Mathematics']
#
# https://arxiv.org/pdf/0704.2511
# ['Performance']
#
# https://arxiv.org/pdf/0704.2668
# ['Feature Selection', 'Algorithms', 'Performance', 'SVM', 'CSS']
#
# https://arxiv.org/pdf/0704.2725
# ['Algorithms', 'Probability', 'Databases', 'Pattern Recognition']
#
# https://arxiv.org/pdf/0704.2857
# ['Probability', 'Graphs', 'Algorithms', 'Performance', 'Memory']
#
# https://arxiv.org/pdf/0704.2902
# ['Graphs', 'Digital Libraries', 'Natural Language Processing', 'Statistics', 'Algorithms']
#
# https://arxiv.org/pdf/0704.3287
# ['Statistics', 'Algorithms', 'Consistency', 'Performance', 'Probability']
#
# https://arxiv.org/pdf/0704.3433
# ['Probability', 'Graphs', 'Graphics', 'Algorithms', 'Mathematics']
#
# https://arxiv.org/pdf/0704.3573
# ['Algorithms', 'Memory', 'Performance', 'Processors', 'Hardware']
#
# https://arxiv.org/pdf/0705.0044
# ['Memory', 'Graphs', 'Storage', 'Algorithms', 'Probability']
#
# https://arxiv.org/pdf/0705.0086
# ['Algorithms', 'Pattern Recognition']
#
# https://arxiv.org/pdf/0705.0178
# ['Graphs', 'Probability', 'Graphics', 'Algorithms']
#
# https://arxiv.org/pdf/0705.0204
# ['Performance', 'Algorithms', 'Graphs', 'Image Processing', 'Memory']
#
# https://arxiv.org/pdf/0704.0218
# ['Graphs', 'Algorithms']
#
# https://arxiv.org/pdf/0704.1524
# ['Algorithms', 'Performance', 'Graphs', 'Probability']
#
# https://arxiv.org/pdf/0704.1707
# ['Sound', 'Graphs', 'Algorithms', 'Graphics', 'Memory']
#
# https://arxiv.org/pdf/0704.1829
# ['Algorithms', 'Performance']
#
# https://arxiv.org/pdf/0704.1838
# ['Probability', 'Performance', 'Mathematics', 'Queue', 'Algorithms']
#
# https://arxiv.org/pdf/0704.2375
# ['Algorithms', 'Probability', 'Performance', 'Mathematics']
#
# https://arxiv.org/pdf/0704.2505
# ['Algorithms']
#
# https://arxiv.org/pdf/0704.2609
# ['Consistency', 'Graphs']
#
# https://arxiv.org/pdf/0704.3313
# ['Algorithms', 'Probability', 'Graphs', 'Data Structures', 'Storage']
#
# https://arxiv.org/pdf/0704.3359
# ['Optimization', 'Algorithms', 'Performance', 'SVM', 'Regularization']
#
# https://arxiv.org/pdf/0704.3434
# ['Probability', 'Performance', 'Algorithms', 'Statistics', 'Robotics']
#
# https://arxiv.org/pdf/0704.3536
# ['Graphs', 'Algorithms', 'Graphics', 'Information Theory']
#
# https://arxiv.org/pdf/0704.3635
# ['Algorithms', 'Databases', 'Data Mining', 'Statistics', 'Consistency']
#
# https://arxiv.org/pdf/0704.3662
# ['Devices', 'Performance', 'Statistics', 'Graphs', 'Information Theory']
#
# https://arxiv.org/pdf/0704.3665
# ['Devices', 'Statistics', 'Information Retrieval', 'Natural Language Processing', 'Software Engineering']
#
# https://arxiv.org/pdf/0704.3674
# ['Graphs', 'Mathematics']
#
# https://arxiv.org/pdf/0704.3773
# ['Performance', 'Algorithms', 'Data Structures', 'Python', 'Memory']
#
# https://arxiv.org/pdf/0704.3880
# ['Queue', 'Performance', 'Algorithms', 'Probability', 'Game Theory']
#
# https://arxiv.org/pdf/0704.3969
# ['Performance', 'Probability', 'Statistics', 'Optimization']
#
# https://arxiv.org/pdf/0705.0150
# ['Mathematics', 'Algorithms', 'Probability', 'Optics', 'Graphs']
#
# https://arxiv.org/pdf/0705.0214
# ['Regularization', 'Graphs', 'Statistics', 'Stack', 'Mathematics']
#
# https://arxiv.org/pdf/0705.0253
# ['Algorithms', 'Probability', 'Storage', 'Dynamic Programming', 'Graphs']
#
# https://arxiv.org/pdf/0705.0286
# ['Algorithms', 'Performance', 'Graphs', 'Memory', 'Consistency']
#
# https://arxiv.org/pdf/0704.0046
# ['Probability', 'Memory', 'Statistics', 'Information Theory']
#
# https://arxiv.org/pdf/0704.0590
# ['Algorithms', 'Memory', 'Graphs', 'VLSI', 'Hardware']
#
# https://arxiv.org/pdf/0704.0047
# ['Probability', 'RNN', 'Statistics', 'Databases', 'Performance']
#
# https://arxiv.org/pdf/0704.0788
# ['Algorithms', 'Processors', 'Performance', 'Probability']
#
# https://arxiv.org/pdf/0704.1198
# ['Algorithms', 'Consistency', 'Performance', 'Optimization', 'Graphs']
#
# https://arxiv.org/pdf/0704.1409
# PDF file is not found!
# []
#
# https://arxiv.org/pdf/0704.1709
# ['Algorithms', 'Graphs', 'Statistics', 'Databases']
#
# https://arxiv.org/pdf/0704.1748
# ['Graphs', 'Algorithms', 'Optimization', 'Databases', 'Clustering']
#
# https://arxiv.org/pdf/0704.2083
# ['Statistics', 'Java', 'Frontend', 'Graphs', 'Probability']
#
# https://arxiv.org/pdf/0704.2353
# ['Probability', 'Devices', 'Graphs', 'Statistics', 'Signal Processing']
#
# https://arxiv.org/pdf/0704.3035
# ['Probability', 'Memory']
#
# https://arxiv.org/pdf/0704.3157
# ['Databases', 'SQL', 'Memory', 'Graphs', 'Optimization']
#
# https://arxiv.org/pdf/0704.3199
# ['Graphs', 'Probability', 'Graphics', 'Performance']
#
# https://arxiv.org/pdf/0705.0025
# ['Storage', 'Probability']
#
# https://arxiv.org/pdf/0704.1818
# ['Graphs', 'Probability', 'Graphics', 'Algorithms', 'Memory']
#
# https://arxiv.org/pdf/0704.1925
# ['Performance', 'Algorithms', 'Statistics', 'Probability']
#
# https://arxiv.org/pdf/0704.2295
# ['Probability', 'Algorithms', 'Graphs', 'Graphics', 'Memory']
#
# https://arxiv.org/pdf/0704.2542
# ['Consistency', 'Performance', 'Virtual Reality', 'Graphs', 'Sound']
#
# https://arxiv.org/pdf/0704.2651
# ['Optimization', 'Statistics']
#
# https://arxiv.org/pdf/0704.2811
# ['Algorithms', 'Graphs', 'Performance']
#
# https://arxiv.org/pdf/0704.2900
# []
#
# https://arxiv.org/pdf/0704.3241
# ['Algorithms', 'Probability', 'Performance', 'Statistics', 'Optimization']
#
# https://arxiv.org/pdf/0704.3316
# ['Statistics', 'Probability', 'Algorithms', 'Graphs']
#
# https://arxiv.org/pdf/0704.3399
# ['Performance', 'Probability', 'Algorithms', 'Optimization']
#
# https://arxiv.org/pdf/0704.3504
# ['Probability', 'Memory', 'Statistics', 'Graphs', 'Graphics']
#
# https://arxiv.org/pdf/0704.3835
# ['Graphs', 'Algorithms', 'Storage', 'Statistics', 'Probability']
#
# https://arxiv.org/pdf/0705.0130
# ['Probability', 'Performance', 'Statistics', 'Graphs']
#
# https://arxiv.org/pdf/0704.0671
# ['Algorithms', 'Statistics', 'Probability', 'Performance', 'Graphs']
#
# https://arxiv.org/pdf/0704.0282
# ['Performance', 'Algorithms', 'Probability', 'Information Theory']
#
# https://arxiv.org/pdf/0704.0838
# ['Probability', 'Optimization', 'Memory', 'Statistics', 'Performance']
#
# https://arxiv.org/pdf/0704.0865
# ['Performance', 'Graphs', 'Graphics', 'Processors', 'Probability']
#
# https://arxiv.org/pdf/0704.0967
# ['Optimization', 'Algorithms', 'Performance', 'Probability', 'Graphs']
#
# https://arxiv.org/pdf/0704.0985
# ['Hardware', 'Algorithms', 'Devices', 'Memory', 'Artificial Intelligence']
#
# https://arxiv.org/pdf/0704.1043
# ['Algorithms', 'Probability', 'Mathematics', 'Statistics', 'Compilers']
#
# https://arxiv.org/pdf/0704.1158
# PDF file is not found!
# []
#
# https://arxiv.org/pdf/0704.1308
# ['Performance', 'Algorithms', 'Statistics', 'Probability', 'Graphs']
#
# https://arxiv.org/pdf/0704.1571
# ['Graphs', 'Algorithms', 'Biology', 'Optimization']
#
# https://arxiv.org/pdf/0704.2351
# PDF file is not found!
# []
#
# https://arxiv.org/pdf/0704.2596
# ['Algorithms', 'Graphs', 'Memory', 'BASE']
#
# https://arxiv.org/pdf/0704.3496
# ['Graphs', 'Algorithms', 'Biology', 'Dynamic Programming', 'Optimization']
#
# https://arxiv.org/pdf/0704.3683
# PDF file is not found!
# []
#
# https://arxiv.org/pdf/0704.3886
# PDF file is not found!
# []
#
# https://arxiv.org/pdf/0705.0081
# ['Graphs', 'Probability']
#
# https://arxiv.org/pdf/0704.0468
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-70e9bb8bd80f> in <module>
#       1 for paper in papers:
#       2     print(paper['url'])
# ----> 3     paper['keywords'] = keywordsFromPaper(paper['url'], keywords)
#       4     print(paper['keywords'])
#       5     print()
#
# <ipython-input-6-e697859b5b3c> in keywordsFromPaper(url, keywords)
#      35       A list of five words that have highest occurences
#      36     '''
# ---> 37     text = readPDF(url)
#      38     occ = countKeywords(text, keywords)
#      39
#
# <ipython-input-6-e697859b5b3c> in readPDF(url)
#       8     Return a text string
#       9     '''
# ---> 10     r = requests.get(url)
#      11     f = io.BytesIO(r.content)
#      12     text = "" # returned text
#
# /opt/anaconda3/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /opt/anaconda3/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# /opt/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /opt/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /opt/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     341         # Trigger any extra validation we need to do.
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#     345             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# /opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     837         # Force connect early to allow us to validate the connection.
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#     841         if not conn.is_verified:
#
# /opt/anaconda3/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     299     def connect(self):
#     300         # Add certificate verification
# --> 301         conn = self._new_conn()
#     302         hostname = self.host
#     303
#
# /opt/anaconda3/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     157         try:
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#     161         except SocketTimeout as e:
#
# /opt/anaconda3/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      68             if source_address:
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#      72
#
# KeyboardInterrupt:

# %% [markdown]
# # Finding
# We successfully generate 4-5 keywords for most papers.
#
#
# Many URLs that the PDF file is unavilable:
# 1. https://arxiv.org/pdf/0704.0213
# 2. https://arxiv.org/pdf/0704.1409
# 3. https://arxiv.org/pdf/0705.1442
# 4. https://arxiv.org/pdf/0707.0454
# 5. https://arxiv.org/pdf/0706.1002
# 6. https://arxiv.org/pdf/0706.0484
# 7. https://arxiv.org/pdf/0706.1118
# 8. https://arxiv.org/pdf/0706.1477
# 9. https://arxiv.org/pdf/0706.2073
# 10. https://arxiv.org/pdf/0706.2153
#
# and so on.

# %% [markdown]
# ### Text Cleansing
# Let's clean text for further machine learning works

# %%
from bs4 import BeautifulSoup
import re
import string
import copy

# Funtion to remove HTML tags
def removeHTMLTags(text):
    return BeautifulSoup(text, 'html.parser').get_text()

# Function to remove more special characters and escape characters
def removeExtraWhitespaceEsc(text):
    #pattern = r'^\s+$|\s+$'
    pat = r'^\s*|\s\s*'
    return re.sub(pat, ' ', text).strip()

# Function to remove commas and periods
def removeCommasPeriods(text):
    pat = r'[.,]+'
    return re.sub(pat, '', text)

# Function to remove words that include special character
def removeSpecialCharacterWords(text):
    # define the pattern to keep only letters, numbers, dash and white spaces
    pat = r'[a-zA-Z0-9]*[^a-zA-Z0-9_\s]+[a-zA-Z0-9]*'
    return re.sub(pat, '', text)

def cleanText(text):
    clean_text = removeHTMLTags(text)
    clean_text = removeExtraWhitespaceEsc(clean_text)
    clean_text = removeCommasPeriods(clean_text)
    clean_text = removeSpecialCharacterWords(clean_text)
    return clean_text

# %%
# Sample paper

# Keywords from doing keywords matching
# ['Probability', 'Statistics', 'Graphs', 'Image Processing', 'Signal Processing']

url = "https://arxiv.org/pdf/0705.0043.pdf"
text = readPDF(url)
clean_text = cleanText(text)
clean_text
# Out:
# 'Joint Detection and  of an Unobservable Change in the Distribution of a Random Sequence SavasDayanikandChristianGoulding HVincentPoor Dept ofOperations ResearchandFinancialEngineering SchoolofEngineering andAppliedScience PrincetonUniversity Princeton NJ08544 Princeton UniversityPrinceton NJ08544       Decision strategies for the joint problemhave a wide array  of applications such as fault detection and isolation in  in the probabilitydistribution  of a sequence  7 of independent and identically distributed  random fensepatternrecognitionandmachinelearningradarandsonar 0   The  signal processing seismology speech and image processing 0 jective is quick detectionof the change and   2 ence of the ensuing pdf Followinga Bayesian approacha the theoryhasnotbeenbroadlydeveloped   r newsequentialdecisionstrategyforthisproblemisrevealed  p A andisprovenoptimal  timalityfora  egyaredemonstratedvianumericalexamples eralizes these results throughthe developmentof  0 theoreticboundsandtheapplicationoflikelihoodmethods In 3 thispaperwe followa  I INTRODUCTION   T Consider a sequence of iid randomvariables X X  mericalschemeforitsimplementation 1 2 I takingvaluesin some measurablespace  Thecommon InSecIIweformulatepreciselytheprobleminaBayesian  s  frameworkandinSecIIIweshowthatitcanbereducedtoan c  ability measureP0 on  andthen at some unobservable optimalstoppingofaMarkovprocesswhosestatespaceisthe disorder time  the common probability distribution changes standardprobabilitysimplexInadditionweestablishasimple 1 v  recursiveformulathatcapturesthedynamicsoftheprocessand 3 able index   M   The objective is to detect  4  In Sec IV we use optimal stopping theory to substantiate 0 tifythenewprobabilitydistributionasaccuratelyaspossibleso the optimality equation for the value function of the optimal 0 thatthemostsuitableactionscanbetakenwiththeleastdelay stoppingproblem Moreoverweprovethatthisvaluefunction  5   0 tal areas of sequential  change detection and  itysimplexandthattheoptimalstoppingregionconsistsofM 7 hypothesis testing In traditional change detection problems   0  there is only one change distribution  therefore the focus sideratruncatedversionoftheproblemthatallowsatmostN v isexclusivelyondetectingthechangetime  observationsfromthesequenceofrandommeasurements We Xi   change time to consider Instead every observation has  approximationerrorassociatedwiththistruncatedproblem r a    In Sec V we show that the separate problems of change  Bothofthesesubproblemshave  beenstudiedextensively Forrecentreviewsoftheseareaswe special cases of the overall joint solution We illustrate some  geometricalpropertiesofthe optimalmethodanddemonstrate  itsimplementationbynumericalexamplesforthespecialcases not taken into account by separately applying techniques for M  2andM  3  these subproblems While raising an alarm as soon as the the M convexsubsets comprisingthe optimalstoppingregion change occurs is advantageous for the change detection task are connected and instances in which they are not Likewise it is undesirable for the  task because waiting we show that the continuationregion  the complementof   tribution Likewise the unknown change time complicates  the  task and as a result adaptation of existing sequential  testing algorithms is problematic II PROBLEM STATEMENT Let  be a probability space hosting random   ables      and     M    TheresearchofH VincentPoorwassupportedinpartbytheUSArmyPantheonProject andaprocessX  1takingvaluesinsomemeasurable    III POSTERIORANALYSIS AND FORMULATION AS AN   wehave OPTIMALSTOPPING PROBLEM     In this section we show that the Bayes risk function in  canbe writtenas theexpectedvalueof the    n n   nalcostsdrivenbya certainMarkovprocess We use thisfact    to recast the minimum Bayes risk in  as a Markov optimal   1 Y  stoppingproblem forsomegivenprobabilitymeasuresP0P1PM  Letusintroducetheposteriorprobabilityprocesses known constants p   p   and   0i  M such    1 where    and   and       Namely  is indepen ...

# %% [markdown]
# ### 2.2 SpaCy

# %%
# Download "en_core_sci_lg"
# pip install scispacy
# pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.4.0/en_core_sci_lg-0.4.0.tar.gz

# %%
import spacy

nlp = spacy.load("en_core_sci_lg")
kws = nlp(clean_text)
kws.ents
# Out:
# (Joint Detection,
#  Change,
#  Distribution,
#  Random Sequence SavasDayanikandChristianGoulding HVincentPoor Dept ofOperations,
#  ResearchandFinancialEngineering,
#  SchoolofEngineering,
#  Decision strategies,
#  joint problemhave,
#  applications,
#  fault,
#  detection,
#  isolation,
#  probabilitydistribution,
#  sequence,
#  independent,
#  signal processing,
#  seismology,
#  speech,
#  image processing,
#  jective,
#  detectionof,
#  change,
#  ence,
#  pdf Followinga Bayesian approacha,
#  theoryhasnotbeenbroadlydeveloped,
#  newsequentialdecisionstrategyforthisproblemisrevealed,
#  andisprovenoptimal,
#  egyaredemonstratedvianumericalexamples,
#  eralizes,
#  results,
#  throughthe developmentof,
#  theoreticboundsandtheapplicationoflikelihoodmethods,
#  thispaperwe,
#  followa,
#  T,
#  sequence,
#  iid randomvariables X X,
#  measurablespace,
#  Thecommon,
#  measureP0,
#  andthen,
#  optimalstoppingofaMarkovprocesswhosestatespaceisthe disorder,
#  time,
#  probability,
#  distribution,
#  standardprobabilitysimplexInadditionweestablishasimple 1,
#  objective,
#  detect,
#  Sec IV,
#  optimal,
#  theory,
#  tifythenewprobabilitydistributionasaccuratelyaspossibleso,
#  optimality equation,
#  value function,
#  optimal,
#  thatthemostsuitableactionscanbetakenwiththeleastdelay stoppingproblem,
#  Moreoverweprovethatthisvaluefunction,
#  tal areas,
#  sequential,
#  detection,
#  itysimplexandthattheoptimalstoppingregionconsistsofM,
#  hypothesis testing,
#  detection,
#  problems,
#  distribution,
#  isexclusivelyondetectingthechangetime,
#  observationsfromthesequenceofrandommeasurements,
#  Xi   ,
#  observation,
#  approximationerrorassociatedwiththistruncatedproblem,
#  Sec V,
#  separate,
#  problems,
#  change,
#  Bothofthesesubproblemshave,
#  Forrecentreviewsoftheseareaswe special,
#  joint solution,
#  geometricalpropertiesofthe,
#  optimalmethodanddemonstrate,
#  itsimplementationbynumericalexamplesforthespecialcases,
#  techniques,
#  M  2andM  3  ,
#  subproblems,
#  alarm,
#  M convexsubsets comprisingthe,
#  optimalstoppingregion,
#  detection,
#  task,
#  task,
#  continuationregion,
#  complementof,
#  tribution,
#  task,
#  adaptation,
#  sequential,
#  algorithms,
#  problematic II PROBLEM STATEMENT,
#  probability,
#  ables,
#  TheresearchofH,
#  FORMULATION AS AN,
#  PROBLEM     ,
#  section,
#  Bayes risk function,
#  canbe writtenas theexpectedvalueof,
#  nalcostsdrivenbya certainMarkovprocess,
#  thisfact,
#  Bayes risk,
#  Markov optimal,
#  Letusintroducetheposteriorprobabilityprocesses,
#  independentof,
#  Mn,
#  observations,
#  posterior,
#  probability,
#  change,
#  terminologyof,
#  Sec  ,
#  reducesto,
#  occurredat,
#  stage,
#  posterior joint,
#  dardgeometricdistributionwhenp0,
#  probabilitythatthechangehasoccurredbystagenandthatthe,
#  iiscorrect,
#  Theconnectionoftheseposterior,
#  inthenextproposition,
#  probability,
#  measures,
#  densities,
#  measure,
#  Proposition1,
#  sequentialdecisionstrategy         0as  ,
#  objective,
#  detect,
#  X X X      ,
#  values,
#  accuratelyas,
#  givencosts,
#  Proposition1,
#  equivalentversion,
#  associated with,
#  detectiondelay false alarm,
#  false,
#  Bayes risk function,
#  posterior,
#  distributions,
#  cation,
#  change index,
#  ThisisparticularlyeffectiveinlightofProposition,
#  LetF,
#  isreferredtothroughoutthepaper,
#  Fn,
#  SM,
#  terminal,
#  decision rule,
#  mappings,
#  SM,
#  E    M,
#  measurablewith respecttothe historyF      D,
#  ofobservationprocessX,
#  Applyingastrategy  f      thatthe D,
#  commonpdfhaschangedfromf tof,
#  denotethecollectionofallsuchsequentialdecisionstrategies,
#  Bayesrisk     function,
#  ZE,
#  Proposition2,
#  tion,
#  cost,
#  terminal,
#  decision,
#  alarm,
#  aij  0i,
#  M,
#  process,
#  submartingale,
#  knownconstantssatisfyingaii,
#  nocostfora,
#  process,
#  problem,
#  sequential,
#  decision strategy,
#  processand,
#  enoughto,
#  F,
#  overforeveryboundedfunctionf,
#  SM,
#  Randn,
#  martingale,
#  OPTIMAL,
#  STOPPINGTHEORY,
#  Proposition,
#  section,
#  optimal,
#  solution,
#  functionshh1hM,
#  SM,
#  Theoptimalityequation M,
#  integers,
#  collections,
#  CN,
#  families,
#  event,
#  terminal,
#  investigate,
#  optimal,
#  stopping,
#  problems,
#  sion,
#  words,
#  optimal,
#  terminal,
#  decision,
#  supermartingale,
#  thatthefunctionsh,
#  andh1hM,
#  Lemma4      ,
#  eral,
#  properties,
#  Snell,
#  envelopes,
#  R,
#  results,
#  arbitrary,
#  state vector,
#  tablish,
#  optimality equation,
#  formulation,
#  C       Lemma 5,
#  N  0,
#  tions,
#  N  1,
#  nal decision,
#  SM,
#  F,
#  integrable random,
#  ables,
#  F andour cideinthelimitasN,
#  Thatis,
#  operator M,
#  collection,
#  Mf,
#  Proposition15 Forevery N  0,
#  SM,
#  nonnegativeboundedfunction,
#  M2f,
#  iscontinuous,
#  nonnegative,
#  Mnf     ,
#  iscontinuous,
#  NotethatSM,
#  nuityofV  followsfromtheconcavity 0 Lemma 8,
#  N  0,
#  onallofSMincludingitsboundary,
#  nextlemma showshow,
#  optimalstoppingproblems C Anoptimalsequentialdecisionstrategy P,
#  operator M,
#  FinallywedescribetheoptimalstoppingregioninSM,
#  connection,
#  truncated,
#  optimal,
#  value function V,
#  optimal,
#  sequentialdecisionstrategyforourproblem,
#  Lemma9,
#  F0,
#  SM,
#  SM,
#  probability space,
#  SM,
#  unit,
#  theprecedingresultsremainvalid,
#  tor,
#  zero,
#  component,
#  component,
#  extremepointsof,
#  closed convexset,
#  SM,
#  tor,
#  SM,
#  expressed,
#  convergence theorem,
#  side yields,
#  Hencewehaveshownthefollowingresult             M,
#  state,
#  SM,
#  FurthermoreSM,
#  solution,
#  original,
#  problem,
#  erty  ,
#  Proposition 2,
#  P B Somepropertiesofthevaluefunction Theorem19         n   F,
#  resultshelpusto,
#  anoptimal,
#  variable,
#  optimal,
#  solutionforV,
#  nextsubsection,
#  SM,
#  R,
#  thensoisTg   ,
#  optimalstoppingrule,
#  isgivenby,
#  Proposition 13,
#  mappings,
#  minaldecisionruled,
#  Proposition14 ForeveryN     ,
#  ontheevent     khk2 khk 1 V      0 0 0 c p N    ,
#  Theorem17 revealsits,
#  SM,
#  limN,
#  stratetheuseoftheseresultsinthenumericalexamplesofSec V    V 0,
#  N  0,
#  path,
#  realizations,
#  optimal,
#  terminate,
#  experimentsin,
#  N ple,
#  shaded area,
#  solid boundaryrepresents,
#  theoptimalstoppingregionwhiletheunshadedarearepresents,
#  thecontinuationregion V SPECIAL CASES,
#  convex,
#  subsets,
#  optimal,
#  stopping region,
#  instancesin,
#  Bayes risk function,
#  ThisistheBayesriskstudiedbyShiryaev,
#  tinuationregionisdisconnected,
#  implementation,
#  optimal,
#  Sec IVC,
#  Setp0,
#  sition,
#  eachobservationXnisrealizedStoptakingobservationswhen  thestatistic      ,
#  Wolfowitz  ,
#  Arrow Blackwell,
#  Theoptimalterminaldecisionis baseduponwhether,
#  statistic  ,
#  C Twoalternativesafterthechange,
#  gorithm,
#  canintersect,
#  distributions,
#  boundariesand,
#  stop,
#  graphicalrepresentationof,
#  Inthiscase eitherofthedecisionsd,
#  continuation regions,
#  arbitrary,
#  optimal,
#  specialcase M,
#  Thenwe,
#  representationto     tocomputeV  viamodelinstancesforcertainchoicesofthemodelparameters,
#  sionregionismappedintotheplaneviaL,
#  linear mapping L  R3  R2,
#  techniques,
#  computing,
#  value function,
#  optimality,
#  equationsuchasvalueiteration,
#  clidean,
#  distance fromthe,
#  image,
#  edge,
#  whichwehavethreepossiblechangedistributionsf   1 2 image,
#  image point  ,
#  Forexamplethedistancefromtheimage setsofS3,
#  rotation,
#  decision region,
#  model,
#  phasizetheirsourceinS2 f0  14141414  ,
#  section,
#  ures,
#  case,
#  coordinate,
#  illustratecertaingeometricalpropertiesofthecontinuationand,
#  image,
#  REFERENCES,
#  quickest,
#  detection,
#  Teor,
#  Theory  A N Shiryaev,
#  Optimal,
#  New York,
#  T L Lai Sequential,
#  problems,
#  AWaldandJWolfowitzBayes,
#  solutionsofsequential,
#  Sequential,
#  fault,
#  stochastic systems IEEE Trans Inform Theory cisions,
#  Programming)

# %% [markdown]
# ### 2.3 YAKE

# %%
# Install yake
# pip install yake

# %%
import yake

kw_extractor = yake.KeywordExtractor()
language = "en"
max_ngram_size = 2
deduplication_threshold = 0.1
numOfKeywords = 20
custom_kw_extractor = yake.KeywordExtractor(lan=language, n=max_ngram_size, dedupLim=deduplication_threshold, top=numOfKeywords, features=None)
yake_kws = custom_kw_extractor.extract_keywords(clean_text)
yake_kws
    
# The lower the score, the more relevant the keyword is
# Out:
# [('optimal stopping', 5.991492767714389e-05),
#  ('change Bothofthesesubproblemshave', 0.0007951985018384505),
#  ('Sec', 0.006049226106331996),
#  ('York', 0.01595597549885864),
#  ('rule', 0.017733541510212118),
#  ('pdf', 0.027729471727509364),
#  ('jth', 0.06693521255547354)]

# %% [markdown]
# ### 2.4 Rake-Nltk

# %%
# Install Rake-Nltk
# pip install rake-nltk

# %%
from rake_nltk import Rake
r = Rake(max_length=3)  # uses stopwords for english from NLTK, and all puntuation characters

# Keywords from title
r.extract_keywords_from_text(clean_text)
rake_kws = r.get_ranked_phrases()
rake_kws
# Out:
# ['snell envelopes finally',
#  'shaded area including',
#  'setting p p',
#  'resultshelpusto establish anoptimal',
#  'probabilitiestothelossstructureforourproblemisestablished inthenextproposition tively',
#  'precisely givencosts ables',
#  'new awaldandjwolfowitzbayes solutionsofsequential',
#  'monotone convergence theorem',
#  'minimum bayes risk',
#  'measurablewith respecttothe historyf',
#  'measurablespace thecommon inseciiweformulatepreciselytheprobleminabayesian',
#  'lectionofboundedfunctionsf denotethecollectionofallsuchsequentialdecisionstrategies p',
#  'l lai sequential',
#  'geometricalpropertiesofthe optimalmethodanddemonstrate itsimplementationbynumericalexamplesforthespecialcases',
#  'following f2 f3',
#  'canbe writtenas theexpectedvalueof',
#  'also conveys finallywedescribetheoptimalstoppingregioninsm',
#  'bayesrisk function ze',
#  'bayes risk function',
#  'posterior distributions cation',
#  'n observations andp',
#  'fault dblackwell andmagirshicktheoryofgamesandstatistical',
#  'x r inf',
#  'value function via',
#  'substantiate 0 tifythenewprobabilitydistributionasaccuratelyaspossibleso',
#  'x x x',
#  'xi change time',
#  'h h also',
#  'closed convexset sm',
#  'index satisfying h',
#  'every s2 r3',
#  'every component except',
#  'wehave optimalstopping problem',
#  'unit j theprecedingresultsremainvalid',
#  'limit lim exists',
#  'let us introduce',
#  'complementof tribution likewise',
#  'boundedonsm n n',
#  'bounded functionsf observe',
#  '3 thispaperwe followa',
#  '0 mf h',
#  'stopping rules 0',
#  'value function v',
#  'optimal stopping time',
#  'n 1 second',
#  'g sm r',
#  'terminal decision rule',
#  'sequential change detection',
#  'thenlemma9impliesthat e e',
#  'terminal 0 0',
#  'c twoalternativesafterthechange n',
#  'c lemma 5',
#  'optimality equation note',
#  'every n 1',
#  'every n 0',
#  '0 n n',
#  'overall joint solution',
#  'optimal stopping region',
#  'optimal stopping problems',
#  'process f consists',
#  'enoughto consider f',
#  'separately applying techniques',
#  'proposition1 gives us',
#  'detectiondelay false alarm',
#  '2 thenwe use',
#  '0j ij fig',
#  'change detection task',
#  'markov optimal 1',
#  'value function',
#  'optimality equation',
#  'n n',
#  'fault detection',
#  'stopping region',
#  'n 0',
#  'joint detection',
#  'change index',
#  'x respectively',
#  'e e',
#  'e 0',
#  '0 0',
#  'every c',
#  'decision region',
#  'approximationerrorassociatedwiththistruncatedproblem r',
#  'c 0',
#  'upon stopping',
#  'stopping times',
#  'every point',
#  'threealternativesafterthechange s2',
#  'stage n',
#  'sion rule',
#  'sec v',
#  'posterior probability',
#  'one note',
#  'n wolfowitz',
#  'n ple',
#  'lemma 18',
#  'jth component',
#  'mn 0',
#  'mappings 0',
#  'j 1',
#  'optimal specialcase',
#  'optimal solution',
#  'unobservable change',
#  'separate problems',
#  'nal decision',
#  'joint problemhave',
#  'classical problems',
#  'pdf f',
#  'every strategy',
#  'tor sm',
#  'fn sm',
#  'optimal strategy',
#  'wide array',
#  'webeginbyapplyingthemethodoftruncationwithaview minh',
#  'use thisfact',
#  'unobservable random',
#  'uniformly bounded',
#  'tor consisting',
#  'terminologyof sec',
#  'similar approach',
#  'sec ivc',
#  'sec iv',
#  'respectively accordingly',
#  'r2 foreverypoint',
#  'quick detectionof',
#  'proposition 2',
#  'probability space',
#  'pair consistingof',
#  'nextlemma showshow',
#  'manner similar',
#  'j j',
#  'gorithm canintersect',
#  'false s3',
#  'eachobservationxnisrealizedstoptakingobservationswhen thestatistic',
#  'continuation regions',
#  'arrow blackwell',
#  '2andm 3',
#  '2 ence',
#  '1954 edition',
#  'updatethe statistic',
#  'special case',
#  'sequence 7',
#  'result adaptation',
#  'previous subsection',
#  'detect 4',
#  'arbitrary instance',
#  'aij 0i',
#  'accuratelyas possible',
#  'h',
#  'n',
#  '1',
#  '0',
#  'optimal',
#  'change',
#  'f',
#  'sm',
#  'c',
#  'use',
#  'techniques',
#  'task',
#  'solution',
#  'proposition1',
#  'process',
#  'problem',
#  'markov',
#  'limit',
#  'likewise',
#  'let',
#  'j',
#  'ij',
#  'gives',
#  'fig',
#  'false',
#  'consider',
#  'bounded',
#  'applying',
#  'alarm',
#  '3',
#  '2',
#  'strategy',
#  'subsection',
#  'statistic',
#  'sequence',
#  'result',
#  'possible',
#  'instance',
#  'detect',
#  'case',
#  '0i',
#  'zero',
#  'yet',
#  'words',
#  'waiting',
#  'variable',
#  'values',
#  'undesirable',
#  'theoptimalityequation',
#  'terms',
#  'terminate',
#  'takingvaluesin',
#  'taken',
#  'take',
#  'tablish',
#  'sup',
#  'subproblems',
#  'stop',
#  'soon',
#  'solving',
#  'since',
#  'simplify',
#  'shows',
#  'showing',
#  'show',
#  'set',
#  'seek',
#  'section',
#  'rotation',
#  'rewritten',
#  'results',
#  'respect',
#  'references',
#  'reducesto',
#  'recover',
#  'recast',
#  'realizations',
#  'raising',
#  'prove',
#  'probabilitydistribution',
#  'present',
#  'path',
#  'passing',
#  'part',
#  'optimalstoppingproblems',
#  'opposite',
#  'operator',
#  'onallofsmincludingitsboundary',
#  'occurredat',
#  'observed',
#  'objective',
#  'nonnegative',
#  'namely',
#  'measure',
#  'isolation',
#  'iscontinuous',
#  'investigate',
#  'introduction',
#  'interpreted',
#  'instancesin',
#  'instances',
#  'initialize',
#  'independentof',
#  'independent',
#  'imply',
#  'implementation',
#  'image',
#  'illustratecertaingeometricalpropertiesofthecontinuationand',
#  'illustrate',
#  'hand',
#  'graphicalrepresentationof',
#  'given',
#  'functionshh1hm',
#  'formulation',
#  'families',
#  'face',
#  'extremepointsof',
#  'expressed',
#  'experimentsin',
#  'event',
#  'equivalentversion',
#  'equal',
#  'edge',
#  'distribution',
#  'described',
#  'describe',
#  'derive',
#  'depict',
#  'coordinate',
#  'continuationregion',
#  'connection',
#  'connected',
#  'computing',
#  'collections',
#  'collection',
#  'capture',
#  'called',
#  'boundariesand',
#  'associated',
#  'arrive',
#  'applications',
#  'andthen',
#  'advantageous',
#  'account']

# %% [markdown]
# ### 2.5 Gensim

# %%
# Install Gensim
# !python -m pip install gensim==3.8.3

# %%
from gensim.summarization import keywords
gensim_kws = keywords(clean_text)
gensim_kws
# Out:
# 'optimality\nchange\nchanges\nuse optimal stopping theory\nproblems\nproblem\ndecision\nrandom\nstop\nfunction\nimage\ndetection\ndetect\nsequential\ndistribution\ndistributed\ndistributions\nlemma eral useful\nproposition\nprocessing\nprocess\njoint\nprobability\nobservation\nobserved\nobservations\nobserve\nlet\nables\nareas\narea\nconvergence theorem\nisgivenby\nrule\nrules\ntime\ntimes\nyork\nable index\ntheoptimalstoppingregionwhiletheunshadedarearepresents\ninthenextproposition\nsec\nenvelopes\nprobabilitythatthechangehasoccurredbystagenandthatthe\nconsider\nwrittenas\nfalse\noptimalmethodanddemonstrate\ntocomputev\nsimilar\nrespecttothe\nestablish\nthecommon\ndynamic\nknown\ntribution\nbounded\nthatis\nstoppingproblem\nnew\nhypothesis testing\ninthiscase eitherofthedecisionsd\ninf\ncorollary\ndenote tnhe\nthefunctionv\nregular supermartingale\nconvex subsets\neralizes\nresult\nterminal\nterminate\narbitrary initial state\nresults throughthe developmentof\nvincentpoorwassupportedinpartbytheusarmypantheonproject\niii\ninitialize\nregion\nregions\nsense\nbayesian'

# %% [markdown]
# ## Finding
# The text that we read from online pdf files is not in a good shape, e.g. no white space between words. This make it hard for machine learning algorithms to work well.
